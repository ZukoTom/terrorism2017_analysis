# %%
#librairies
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

# %%
#import des donnees avec selection des colonnes pertinentes
#on a fait un prétraitement sur le serveur du CNAM pour ne conserver que l'année 2017 (le fic originel tres loud)
d = pd.read_csv('Sans nom 1.csv')#, usecols=['country_txt','region_txt','latitude','longitude','doubtterr','multiple','success',\
                  #'suicide','attacktype1_txt','targtype1_txt','natlty1_txt','nperpcap','weaptype1_txt',\
                  #'nkill','nkillter','nwound','INT_LOG'])
# Out:
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (19,30,36,40,42,44,48,50,52,56,63,66,75,77,91,93,99,124,131) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
d[:3]
# Out:
#         eventid  iyear  imonth  iday approxdate  extended  resolution  \
# 0  201612150072   2017       1     2        NaN         1         NaN
# 1  201612270022   2017       1     3        NaN         0         NaN
# 2  201612280045   2017       1     1        NaN         0         NaN
#
#    country                       country_txt  region  ...  \
# 0        4                       Afghanistan       6  ...
# 1      195                             Sudan      11  ...
# 2      229  Democratic Republic of the Congo      11  ...
#
#                                               scite1  \
# 0  "11 construction firm workers released in Kand...
# 1  "Bandits Murder Two In Darfur Robbery," Radio ...
# 2  "Fresh 'Rebel' Attacks In East DR Congo Leave ...
#
#                                               scite2  \
# 0  "Taliban kidnap 10 laborers in Kandahar," Pajh...
# 1                                                NaN
# 2  "Latin American Herald Tribune - At Least 14 C...
#
#                                               scite3  \
# 0  "Gunmen abduct 10 workers in southern Afghanis...
# 1                                                NaN
# 2                                                NaN
#
#                    dbsource  INT_LOG  INT_IDEO  INT_MISC INT_ANY  \
# 0  START Primary Collection        0         0         0       0
# 1  START Primary Collection       -9        -9         0      -9
# 2  START Primary Collection        0         1         0       1
#
#                       related Unnamed: 135
# 0                         NaN          NaN
# 1                         NaN          NaN
# 2  201612280045, 201612280046          NaN
#
# [3 rows x 136 columns]

# %%
#on réaligne certaines lignes décallées des colonnes
matching_rows = d.natlty1.str.contains('[a-zA-Z]', regex= True, na=False)
while True in matching_rows.to_numpy(): 
    d.loc[matching_rows, 'natlty1':] = d.loc[matching_rows, 'natlty1':].shift(-1, axis = 1)
    matching_rows = d.natlty1.str.contains('[a-zA-Z]', regex= True, na=False)
matching_rows.unique()
# Out:
# array([False])

# %%
matching_rows2 = d.guncertain1.str.contains('[a-zA-Z]', regex= True, na=False)
while True in matching_rows2.to_numpy(): 
    d.loc[matching_rows2, 'guncertain1':] = d.loc[matching_rows2, 'guncertain1':].shift(-1, axis = 1)
    matching_rows2 = d.guncertain1.str.contains('[a-zA-Z]', regex= True, na=False)
matching_rows2.unique()
# Out:
# array([False])

# %%
matching_rows3 = d.weaptype1.isnull()
while True in matching_rows3.to_numpy(): 
    d.loc[matching_rows3, 'weaptype1':] = d.loc[matching_rows3, 'weaptype1':].shift(-1, axis = 1)
    matching_rows3 = d.weaptype1.isnull()
matching_rows3.unique()
# Out:
# array([False])

# %%
#matching_rows3 = d.INT_LOG.str.contains('[a-zA-Z]', regex= True, na=False)
#while True in matching_rows3.to_numpy(): 
    #d.loc[matching_rows3, 'INT_LOG':] = d.loc[matching_rows3, 'INT_LOG':].shift(-1, axis = 1)
    #matching_rows3 = d.INT_LOG.str.contains('[a-zA-Z]', regex= True, na=False)
#matching_rows3.unique()

# %%
#on selectionne les var pertinentes pour notre étude
d2 = d[['country_txt','region_txt','latitude','longitude','doubtterr','multiple','success',\
        'suicide','attacktype1_txt','targtype1_txt','natlty1_txt','nperpcap','weaptype1_txt',\
        'nkill','nkillter','nwound','INT_LOG']]

# %%
#on séléctionne un sous échantillon
dpca = d[['latitude','longitude','nkill','nkillter','nwound']]

# %%
#on exclue les lignes avec des nan (donnees manquantes)
d2 = d2.dropna()
dpca = dpca.dropna()

# %%
#on verifie qu'il ne reste plus de nan
for i in range(len(d2.columns)):
    if (d2[d2.columns[i]].isnull().sum() != 0):#.values):
        print(d2[d2.columns[i]].isnull().sum())
    else:
        print(f"plus de nan (total de nan colonne {i} = {d2[d2.columns[i]].isnull().sum()})")
# Out:
# plus de nan (total de nan colonne 0 = 0)
# plus de nan (total de nan colonne 1 = 0)
# plus de nan (total de nan colonne 2 = 0)
# plus de nan (total de nan colonne 3 = 0)
# plus de nan (total de nan colonne 4 = 0)
# plus de nan (total de nan colonne 5 = 0)
# plus de nan (total de nan colonne 6 = 0)
# plus de nan (total de nan colonne 7 = 0)
# plus de nan (total de nan colonne 8 = 0)
# plus de nan (total de nan colonne 9 = 0)
# plus de nan (total de nan colonne 10 = 0)
# plus de nan (total de nan colonne 11 = 0)
# plus de nan (total de nan colonne 12 = 0)
# plus de nan (total de nan colonne 13 = 0)
# plus de nan (total de nan colonne 14 = 0)
# plus de nan (total de nan colonne 15 = 0)
# plus de nan (total de nan colonne 16 = 0)

# %%
for i in range(len(d2.columns)):
    print(d2.columns[i], d2[d2.columns[i]].unique())
# Out:
# country_txt ['Afghanistan' 'Sudan' 'Democratic Republic of the Congo' 'Turkey'
#  'Pakistan' 'Italy' 'Somalia' 'Bahrain' 'Myanmar' 'Burundi' 'Iraq'
#  'Burkina Faso' 'India' 'Algeria' 'United States' 'Philippines' 'Greece'
#  'Mali' 'Yemen' 'Libya' 'Central African Republic' 'Egypt' 'Lebanon'
#  'Mexico' 'Ethiopia' 'Nigeria' 'Kyrgyzstan' 'Syria' 'Serbia' 'Sweden'
#  'Thailand' 'Iran' 'France' 'United Kingdom' 'West Bank and Gaza Strip'
#  'Ukraine' 'Paraguay' 'Colombia' 'Malaysia' 'Cameroon' 'Russia' 'Kosovo'
#  'South Africa' 'Chile' 'Kenya' 'Israel' 'Saudi Arabia' 'China' 'Nepal'
#  'Ecuador' 'Niger' 'Venezuela' 'South Sudan' 'Canada' 'Bangladesh'
#  'Tajikistan' 'Ireland' 'Peru' 'Angola' 'Dominican Republic' 'Poland'
#  'Jordan' 'Azerbaijan' 'Mozambique' 'Indonesia' 'Germany' 'Brazil'
#  'Macedonia' 'Tunisia' 'Uganda' 'Chad' 'Finland' 'Australia' 'Norway'
#  'Vietnam' 'Tanzania' 'Sierra Leone' 'Sri Lanka' 'Maldives' 'Belgium'
#  'Rwanda' 'Honduras' 'Czech Republic' 'Malta' 'Gabon' 'Laos' 'Austria'
#  'Zambia' 'Argentina' 'Zimbabwe' 'Ivory Coast' 'Papua New Guinea' 'Spain'
#  'Taiwan' 'Jamaica' 'Albania' 'Liberia' 'Georgia' 'Malawi' 'Netherlands'
#  'Latvia']
# region_txt ['South Asia' 'Sub-Saharan Africa' 'Middle East & North Africa'
#  'Western Europe' 'Southeast Asia' 'North America' 'Central Asia'
#  'Eastern Europe' 'South America' 'East Asia'
#  'Central America & Caribbean' 'Australasia & Oceania']
# latitude [31.320556 12.921007  1.452372 ...  2.359673 35.407278  6.900742]
# longitude [ 65.961111  24.318324  29.875162 ...  45.385034  35.942679 124.437908]
# doubtterr [0 1]
# multiple [0. 1.]
# success [1 0]
# suicide [0 1]
# attacktype1_txt ['Hostage Taking (Kidnapping)' 'Armed Assault' 'Bombing/Explosion'
#  'Unknown' 'Assassination' 'Hijacking' 'Unarmed Assault'
#  'Facility/Infrastructure Attack' 'Hostage Taking (Barricade Incident)']
# targtype1_txt ['Business' 'Private Citizens & Property' 'Police'
#  'Religious Figures/Institutions' 'Military' 'Educational Institution'
#  'Unknown' 'Government (General)' 'Transportation'
#  'Terrorists/Non-State Militia' 'Maritime' 'Government (Diplomatic)'
#  'Journalists & Media' 'Utilities' 'NGO' 'Violent Political Party'
#  'Airports & Aircraft' 'Telecommunication' 'Food or Water Supply' 'Other'
#  'Tourists' 'Abortion Related']
# natlty1_txt ['Afghanistan' 'Sudan' 'Democratic Republic of the Congo' 'Turkey'
#  'Pakistan' 'Italy' 'Somalia' 'Bahrain' 'Myanmar' 'Burundi' 'Iraq'
#  'Burkina Faso' 'India' 'Algeria' 'United States' 'Philippines' 'Greece'
#  'Mali' 'Yemen' 'Libya' 'International' 'Egypt' 'West Bank and Gaza Strip'
#  'Mexico' 'Ethiopia' 'Lebanon' 'Nigeria' 'Kyrgyzstan' 'Syria'
#  'Bosnia-Herzegovina' 'Sweden' 'Thailand' 'Iran' 'France'
#  'Northern Ireland' 'Israel' 'Ukraine' 'Great Britain' 'Paraguay'
#  'Colombia' 'Cameroon' 'Russia' 'Kosovo' 'Chile' 'Kenya' 'Saudi Arabia'
#  'Qatar' 'China' 'Nepal' 'Ecuador' 'Niger' 'Venezuela' 'South Sudan'
#  'Canada' 'Bangladesh' 'Tajikistan' 'Central African Republic' 'Ireland'
#  'Peru' 'Angola' 'Dominican Republic' 'Poland' 'Vietnam' 'Azerbaijan'
#  'Mozambique' 'Indonesia' 'Virgin Islands (U.S.)' 'Germany' 'Brazil'
#  'South Africa' 'Macedonia' 'Tunisia' 'Uganda' 'Finland' 'Chad'
#  'Australia' 'Norway' 'Tanzania' 'Sierra Leone' 'Sri Lanka' 'Corsica'
#  'Maldives' 'Republic of the Congo' 'Multinational' 'Belgium' 'Rwanda'
#  'Spain' 'Marshall Islands' 'Czech Republic' 'United Kingdom' 'Jordan'
#  'Malta' 'Gabon' 'Netherlands' 'Austria' 'Zambia' 'Eritrea' 'Argentina'
#  'Zimbabwe' 'Armenia' 'Ivory Coast' 'Papua New Guinea'
#  'United Arab Emirates' 'Taiwan' 'Georgia' 'Jamaica' 'Hungary'
#  'Switzerland' 'Albania' 'Liberia' 'Malaysia' 'Malawi' 'Latvia' 'Denmark']
# nperpcap [0.0 1.0 5.0 2.0 4.0 -99.0 3.0 6.0 7.0 8.0 15.0 10.0 16.0 20.0 12.0 9.0]
# weaptype1_txt ['Firearms' 'Melee' 'Explosives' 'Unknown' 'Chemical' 'Incendiary'
#  'Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)'
#  'Fake Weapons' 'Sabotage Equipment' 'Other']
# nkill ['0' '2' '7' '39' '1' '3' '4' '8' '9' '6' '5' '10' '36' '75' '93' '11'
#  '12' '13' '20' '43' '14' '15' '17' 2.0 '23' '82' '22' '21' '26' '34' '79'
#  '41' '35' '32' '30' '16' '25' '40' '91' '45' '38' '24' '78' '33' '54' 1.0
#  '18' 0.0 '27' '230' '49' '151' '31' '19' '57' 5.0 '53' '127' '266' 35.0
#  '37' '50' '29' '163' '77' '28' 4.0 '200' '65' 27.0 '47' '72' '46' '44'
#  '59' '48' '128' '588' '74' 13.0 '76' '55' '311' '92' '52' '51']
# nkillter [0.0 2.0 1.0 10.0 6.0 3.0 75.0 93.0 11.0 4.0 15.0 20.0 5.0 17.0 7.0 8.0
#  14.0 13.0 9.0 70.0 41.0 32.0 35.0 39.0 30.0 12.0 23.0 16.0 40.0 21.0 22.0
#  18.0 49.0 36.0 151.0 57.0 44.0 19.0 28.0 42.0 45.0 25.0 33.0 31.0 46.0
#  24.0 92.0]
# nwound [0.0 69.0 1.0 2.0 5.0 9.0 60.0 15.0 6.0 11.0 10.0 3.0 4.0 61.0 7.0 12.0
#  8.0 14.0 17.0 24.0 35.0 20.0 51.0 19.0 25.0 13.0 36.0 27.0 30.0 115.0
#  16.0 65.0 41.0 49.0 21.0 56.0 351.0 50.0 47.0 26.0 22.0 100.0 31.0 53.0
#  54.0 33.0 84.0 28.0 43.0 40.0 45.0 136.0 63.0 42.0 18.0 23.0 89.0 55.0
#  64.0 70.0 119.0 52.0 491.0 48.0 87.0 58.0 141.0 32.0 111.0 66.0 101.0
#  38.0 39.0 405.0 46.0 29.0 34.0 851.0 316.0 236.0 140.0 85.0 127.0 37.0
#  81.0]
# INT_LOG ['0' '-9' '1' 0]

# %%
#PARTIE ACP
#prepa donnees on ne prends que les var quant
dpca = dpca.astype(int)
X = dpca.values
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X)
#centrage réduction
X_scaled = scaler.fit(X).transform(X)
#scaler = StandardScaler() # instanciation de l'objet scaler
#X_scaled = scaler.fit_transform(X)

# %%
plt.boxplot(X)
plt.show()

# %%
#on voit que malgré le centrage et la réduction, il y a des données extrèmes 
#qui risquent de trop influencer les PC
plt.boxplot(X_scaled)
plt.show()

# %%
#calcul composantes
from sklearn.decomposition import PCA
pca = PCA()#n_components=3?)
p = pca.fit(X_scaled)
x = np.arange(X.shape[1])
print("Pourcentage de variance expliquée : ")
plt.bar(x, p.explained_variance_ratio_)
print("Composantes principales : ")
#les coordonnées des PC dans le repère des vecteurs variables de depart
print(p.components_)
# Out:
# Pourcentage de variance expliquée :
# Composantes principales :
# [[ 0.08070909 -0.08717632  0.67640182  0.51105547  0.51690348]
#  [-0.70547359  0.69819619  0.10087292  0.04908067  0.04737969]
#  [-0.51643895 -0.52056097  0.0146403  -0.49637269  0.46444257]
#  [ 0.47684133  0.4836623  -0.01257035 -0.50993552  0.52773182]
#  [ 0.04130639  0.00306868  0.72933728 -0.47957618 -0.48616682]]

# %%
from mpl_toolkits.mplot3d import Axes3D
comp = p.transform(X_scaled)
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111, projection="3d", elev=25, azim=65)
x,y,z = comp[:,0], comp[:,1], comp[:,2]
ax.scatter(x,y,z, marker=".")
#ax.text(x,y,z,noms[i])
plt.show()

# %%
dpca.describe()
# Out:
#           latitude    longitude        nkill     nkillter       nwound
# count  9751.000000  9751.000000  9751.000000  9751.000000  9751.000000
# mean     25.167880    52.078761     2.333504     0.757974     2.489591
# std      13.607435    36.862569    10.076464     3.775614    13.868913
# min     -42.000000  -122.000000     0.000000     0.000000     0.000000
# 25%      13.000000    40.000000     0.000000     0.000000     0.000000
# 50%      32.000000    44.000000     1.000000     0.000000     0.000000
# 75%      34.000000    71.000000     2.000000     0.000000     2.000000
# max      63.000000   151.000000   588.000000   151.000000   851.000000

# %%
from sklearn.cluster import KMeans
array = []
for i in range(2,21):
    kmeans_i = KMeans(n_clusters=i, n_init=1, init='random').fit(X_scaled)
    inertie = kmeans_i.inertia_
    array.append(inertie)
plt.bar(range(2,21), array)
plt.show()

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5, n_init=1, init='k-means++').fit(X)
pred = kmeans.predict(X)
print(kmeans.labels_)
# Out:
# [3 1 1 ... 0 3 0]

# %%
fig2 = plt.figure(figsize=(12, 12))
ax2 = fig2.add_subplot(111, projection='3d', elev=15, azim=-55)
# La couleur des points dépend de leur étiquette issue de kmeans 11 (label)
ax2.scatter(comp[:,0], comp[:,1], comp[:,2], c=kmeans.labels_, marker=".")
plt.show()

# %%
#on calcule une matrice de variance covariance sur des données normalisées
#cela revient à calculer une matrice de corrélation
corrM = np.cov(X_scaled, rowvar=False)
corrDf = pd.DataFrame(corrM,columns=dpca.columns,index=dpca.columns)

triangleV = (corrDf.where(np.triu(np.ones(corrDf.shape), k=0).astype(bool)))
                  #.stack()
                  #.sort_values(ascending=False))
print(triangleV)
print(f"Rq : la corrélation des var avec elles mêmes = {covMatrix[0][0]}")
# Out:
#            latitude  longitude     nkill  nkillter    nwound
# latitude   1.000103  -0.077332  0.014327  0.046841  0.021544
# longitude       NaN   1.000103 -0.032907 -0.012938 -0.039702
# nkill           NaN        NaN  1.000103  0.413099  0.418885
# nkillter        NaN        NaN       NaN  1.000103  0.080895
# nwound          NaN        NaN       NaN       NaN  1.000103
# Rq : la corrélation des var avec elles mêmes = 1.0001025641025643
